# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import pandas as pd
from langconv import *

# %%
base_url = 'https://en.wikipedia.org'

def Traditional2Simplified(sentence):
    sentence = Converter('zh-hans').convert(sentence)
    return sentence

# %%
# Parse page
html = urlopen('https://en.wikipedia.org/wiki/Lists_of_people_of_the_Three_Kingdoms')
bs = BeautifulSoup(html, 'html.parser')
links = bs.find('td', {'class':"navbox-list navbox-odd hlist"}).find_all(
    href=re.compile('^(/wiki/List_of_people_of_the_Three_Kingdoms_)'))\

res = []

for link in links:
    table_html = urlopen(base_url + link['href'])
    table_bs = BeautifulSoup(table_html, 'html.parser')
    table = table_bs.find('div', {'class':"mw-parser-output"}).find(
        'table', {'class':"wikitable sortable"}).tbody
    names = []
    for row in table.find_all('tr')[1:]:
        name = row.td
        name_link = name.find('a')
        if name_link and re.search('^(/wiki/)', name_link['href']): # Has link
            s = name.text
            name_en = re.compile(r'[\u4e00-\u9fa5]').split(s)[0] # English name
            name_zh = Traditional2Simplified(s[len(name_en):]) # Chinese name (Simplified)
            if name_en in name_link['title']: # Has own entry
#                 names.append([name_en, name_zh, name.find('a')['href'], name_link['title']])
                names.append([name_en, name_zh, name.find('a')['href']])
    res.extend(names)

# %%
# Save data
header = ['name_en', 'name_zh', 'url']
df = pd.DataFrame(columns=header, data=res)
df.to_csv('./data/people.csv')

# %%
df
# Out:
#           name_en name_zh                                     url
# 0         Bao Xin      鲍信                           /wiki/Bao_Xin
# 1         Bao Xun      鲍勋                           /wiki/Bao_Xun
# 2         Bi Chen      毕谌                           /wiki/Bi_Chen
# 3          Bi Gui      毕轨                            /wiki/Bi_Gui
# 4    Empress Bian     卞皇后  /wiki/Empress_Bian_(Cao_Huan%27s_wife)
# 5    Empress Bian     卞皇后   /wiki/Empress_Bian_(Cao_Mao%27s_wife)
# 6      Bu Lianshi     步练师                        /wiki/Bu_Lianshi
# 7          Bu Zhi      步骘                            /wiki/Bu_Zhi
# 8         Budugen     步度根                           /wiki/Budugen
# 9         Cai Mao      蔡瑁                           /wiki/Cai_Mao
# 10       Cai Yong      蔡邕                          /wiki/Cai_Yong
# 11        Cang Ci      仓慈                           /wiki/Cang_Ci
# 12        Cao Ang      曹昂                           /wiki/Cao_Ang
# 13        Cao Bao      曹豹                           /wiki/Cao_Bao
# 14       Cao Biao      曹彪                          /wiki/Cao_Biao
# 15     Cao Buxing     曹不兴                        /wiki/Cao_Buxing
# 16        Cao Cao      曹操                           /wiki/Cao_Cao
# 17      Cao Chong      曹冲                         /wiki/Cao_Chong
# 18       Cao Chun      曹纯                          /wiki/Cao_Chun
# 19       Cao Fang      曹芳                          /wiki/Cao_Fang
# 20        Cao Gan      曹干                           /wiki/Cao_Gan
# 21       Cao Gong      曹贡                          /wiki/Cao_Gong
# 22        Cao Gun      曹衮                           /wiki/Cao_Gun
# 23       Cao Hong      曹洪                          /wiki/Cao_Hong
# 24       Cao Huan      曹奂                          /wiki/Cao_Huan
# 25        Cao Hui      曹徽      /wiki/Cao_Hui_(Prince_of_Dongping)
# 26       Cao Jian      曹鉴                          /wiki/Cao_Jian
# 27        Cao Jie      曹节                   /wiki/Empress_Cao_Jie
# 28        Cao Jie      曹节                  /wiki/Cao_Jie_(eunuch)
# 29         Cao Ju      曹矩        /wiki/Cao_Ju_(Prince_of_Fanyang)
# ..            ...     ...                                     ...
# 641      Zhou Chu      周处                          /wiki/Zhou_Chu
# 642     Zhou Fang      周鲂        /wiki/Zhou_Fang_(Three_Kingdoms)
# 643      Zhou Jun      周峻                          /wiki/Zhou_Jun
# 644      Zhou Qun      周群                          /wiki/Zhou_Qun
# 645      Zhou Tai      周泰                          /wiki/Zhou_Tai
# 646      Zhou Tai      州泰                /wiki/Zhou_Tai_(Cao_Wei)
# 647      Zhou Xin      周昕            /wiki/Zhou_Xin_(Han_dynasty)
# 648       Zhou Yu      周瑜                           /wiki/Zhou_Yu
# 649       Zhou Yu      周喁                 /wiki/Zhou_Yu_(Renming)
# 650   Empress Zhu     朱皇后          /wiki/Empress_Zhu_(Eastern_Wu)
# 651      Zhu Huan      朱桓                          /wiki/Zhu_Huan
# 652        Zhu Ju      朱据                            /wiki/Zhu_Ju
# 653       Zhu Jun      朱儁             /wiki/Zhu_Jun_(Han_dynasty)
# 654      Zhu Ling      朱灵         /wiki/Zhu_Ling_(Three_Kingdoms)
# 655       Zhu Ran      朱然                           /wiki/Zhu_Ran
# 656        Zhu Yi      朱异           /wiki/Zhu_Yi_(Three_Kingdoms)
# 657       Zhu Zhi      朱治                           /wiki/Zhu_Zhi
# 658     Zhuge Dan     诸葛诞                         /wiki/Zhuge_Dan
# 659     Zhuge Jin     诸葛瑾                         /wiki/Zhuge_Jin
# 660      Zhuge Ke     诸葛恪                          /wiki/Zhuge_Ke
# 661   Zhuge Liang     诸葛亮                       /wiki/Zhuge_Liang
# 662    Zhuge Qiao     诸葛乔                        /wiki/Zhuge_Qiao
# 663    Zhuge Rong     诸葛融                        /wiki/Zhuge_Rong
# 664   Zhuge Shang     诸葛尚                       /wiki/Zhuge_Shang
# 665      Zhuge Xu     诸葛绪                          /wiki/Zhuge_Xu
# 666    Zhuge Xuan     诸葛玄                        /wiki/Zhuge_Xuan
# 667    Zhuge Zhan     诸葛瞻                        /wiki/Zhuge_Zhan
# 668       Zong Yu      宗预                           /wiki/Zong_Yu
# 669      Zou Jing      邹靖                          /wiki/Zou_Jing
# 670        Zuo Ci      左慈                            /wiki/Zuo_Ci
#
# [671 rows x 3 columns]
