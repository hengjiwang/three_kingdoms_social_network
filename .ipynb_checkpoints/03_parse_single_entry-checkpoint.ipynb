# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from collections import defaultdict
import re

# %%
class ParseEntry:
    def __init__(self):
        self.adj = defaultdict(int)

    def count_name(self,text):
        """add name in text (string) into defaultdict self.adj;
        Two consecutive words starting with capital letters is considered as a name"""
        for x in re.finditer(r'[A-Z][a-z]*[\s][A-Z][a-z]*',text):
            self.adj[x.group()] += 1
        return

    @staticmethod
    def load_page(url):
        """Return a BeautifulSoup object of a given url if exists or None"""
        try:
            url = 'https://en.wikipedia.org'+url
            html = urlopen(url)
            bs = BeautifulSoup(html.read(),'html.parser')
        except:
            #if page not exists or page not found
            return None     
        return bs

    def read_page(self,bs):
        """Count name in the bs object"""
        paragraphs = bs.find('div',{'id':'bodyContent'}).find_all('p')
        for p in paragraphs:
            self.count_name(p.text)
        return self.adj

    def edges_to(self,name):
        bs = load_page(name)
        if bs:
            return self.read_page(bs)
        return None

# %%
parser = ParseEntry()
parser.edges_to('/wiki/Liu_Bei')
# Out:
# defaultdict(int,
#             {'Liu Bei': 204,
#              'Eastern Han': 2,
#              'Shu Han': 3,
#              'Three Kingdoms': 16,
#              'Cao Cao': 69,
#              'Emperor Xian': 7,
#              'Cao Pi': 6,
#              'Sun Quan': 25,
#              'Zhuo County': 1,
#              'Zhuo Commandery': 2,
#              'Liu Zhen': 2,
#              'Liu Sheng': 1,
#              'Emperor Jing': 2,
#              'Pei Songzhi': 1,
#              'Liu Fu': 2,
#              'Liu Yan': 1,
#              'Liu Taotu': 1,
#              'Liu Xiong': 1,
#              'Liu Hong': 1,
#              'Lu Zhi': 1,
#              'Gongsun Zan': 5,
#              'Liu Deran': 1,
#              'Yellow Turban': 2,
#              'Zhang Shiping': 1,
#              'Su Shuang': 1,
#              'Guan Yu': 16,
#              'Zhang Fei': 11,
#              'Jian Yong': 1,
#              'Colonel Zou': 1,
#              'Anxi County': 1,
#              'Zhongshan Commandery': 1,
#              'Yellow Turbans': 1,
#              'Xu Province': 15,
#              'Gaotang County': 2,
#              'Dong Zhuo': 2,
#              'Yuan Shao': 19,
#              'Ji Province': 1,
#              'Qing Province': 2,
#              'Pingyuan State': 1,
#              'Pingyuan County': 1,
#              'Tian Kai': 4,
#              'Yuan Tan': 1,
#              'Liu Ping': 1,
#              'Former Lord': 1,
#              'Tao Qian': 9,
#              'Yuan Shu': 11,
#              'Liu Biao': 12,
#              'Zhang Miao': 1,
#              'Yan Province': 1,
#              'Pei County': 3,
#              'Mi Zhu': 2,
#              'Mi Fang': 1,
#              'Chen Gui': 1,
#              'Chen Deng': 2,
#              'Lady Mi': 1,
#              'Upon Tao': 1,
#              'Chen Qun': 1,
#              'Kong Rong': 1,
#              'Ji Ling': 2,
#              'Xuyi County': 1,
#              'Xiapi Commandery': 6,
#              'Cao Bao': 2,
#              'Guangling Commandery': 1,
#              'Haixi County': 1,
#              'Guannan County': 1,
#              'Yu Province': 1,
#              'Gao Shun': 2,
#              'Zhang Liao': 1,
#              'Xiahou Dun': 2,
#              'Dong Cheng': 3,
#              'Zhu Ling': 1,
#              'Shou County': 1,
#              'While Zhu': 1,
#              'Che Zhou': 1,
#              'Sun Qian': 1,
#              'Yellow River': 2,
#              'Liu Dai': 1,
#              'Wang Zhong': 1,
#              'Yan Ford': 1,
#              'Wen Chou': 2,
#              'As Liu': 1,
#              'Runan Commandery': 4,
#              'Xi County': 1,
#              'Liu Pi': 2,
#              'Cao Ren': 3,
#              'Jing Province': 25,
#              'Gong Du': 2,
#              'Cai Yang': 1,
#              'Although Liu': 1,
#              'Xinye County': 1,
#              'Now I': 1,
#              'Yu Jin': 1,
#              'Guo Jia': 2,
#              'Sima Hui': 2,
#              'Pan Degong': 1,
#              'Zhuge Liang': 13,
#              'Pang Tong': 3,
#              'Xu Shu': 1,
#              'Longzhong Plan': 1,
#              'Yi Province': 14,
#              'Liu Cong': 2,
#              'Duodao District': 1,
#              'Jiangling County': 4,
#              'With Guan': 1,
#              'Mian River': 2,
#              'Jiangxia Commandery': 3,
#              'Yangtze River': 1,
#              'Liu Qi': 4,
#              'When Liu': 2,
#              'Lu Su': 5,
#              'Chaisang County': 1,
#              'Red Cliffs': 1,
#              'Xu Huang': 3,
#              'Yue Jin': 1,
#              'Zhou Yu': 3,
#              'Lady Sun': 1,
#              'Nan Commandery': 1,
#              'Liu Zhang': 21,
#              'Zhang Lu': 5,
#              'Hanzhong Commandery': 11,
#              'As Hanzhong': 1,
#              'Fa Zheng': 7,
#              'Zhang Song': 6,
#              'Zhao Yun': 3,
#              'Jiameng Pass': 1,
#              'Meng Da': 4,
#              'On Liu': 1,
#              'Zhang Su': 1,
#              'Yang Huai': 3,
#              'Gao Pei': 3,
#              'Boshui Pass': 1,
#              'Fu County': 1,
#              'Liu Gui': 1,
#              'Ling Bao': 1,
#              'Zhang Ren': 1,
#              'Deng Xian': 1,
#              'Wu Yi': 3,
#              'Li Yan': 2,
#              'Fei Guan': 1,
#              'Liu Xun': 1,
#              'Luo County': 2,
#              'Ma Chao': 4,
#              'Although Chengdu': 1,
#              'Dong He': 1,
#              'After Liu': 1,
#              'Ling Tong': 1,
#              'Gan Ning': 1,
#              'Yiyang County': 2,
#              'Lingling Commandery': 1,
#              'Xiang River': 1,
#              'Sima Yi': 1,
#              'Liu Ye': 1,
#              'Xiahou Yuan': 10,
#              'Zhang He': 10,
#              'Dangqu County': 1,
#              'Qu County': 1,
#              'Ba Commandery': 1,
#              'Baxi Commandery': 1,
#              'Nanzheng County': 2,
#              'Wudu Commandery': 1,
#              'Yangping Pass': 2,
#              'Wu Lan': 1,
#              'Lei Tong': 1,
#              'Chen Shi': 1,
#              'Huang Zhong': 4,
#              'Mount Dingjun': 1,
#              'Both Xiahou': 1,
#              'Zhao Yong': 1,
#              'Du Xi': 1,
#              'Guo Huai': 1,
#              'Han River': 1,
#              'Xie Valley': 1,
#              'Chencang County': 1,
#              'Liu Feng': 4,
#              'Liu Shan': 4,
#              'Wei Yan': 1,
#              'Xu Jing': 1,
#              'Grand Tutor': 1,
#              'Cao Wei': 1,
#              'When Meng': 1,
#              'Qin Mi': 1,
#              'Lu Xun': 4,
#              'Huang Quan': 1,
#              'Luo Guanzhong': 1,
#              'Daoguang Emperor': 1,
#              'Sanyi Temple': 2,
#              'Wuhou District': 2,
#              'Yangtse Evening': 1,
#              'Yu Ze': 1,
#              'Yellow Emperor': 1,
#              'West China': 1,
#              'Shoe Center': 1,
#              'Industrial Zone': 1,
#              'Sun Yanjun': 1,
#              'Chang Fu': 1,
#              'Guan Gong': 1,
#              'Elliot Ngok': 1,
#              'You Yong': 1,
#              'Red Cliff': 1,
#              'Yu Hewei': 1,
#              'Alex Fong': 1,
#              'The Lost': 1,
#              'Yan Yikuan': 1,
#              'Tony Yang': 1,
#              'Dynasty Warriors': 4,
#              'The Gathering': 1,
#              'Portal Three': 1,
#              'San Guo': 1,
#              'Warriors Orochi': 1,
#              'Samurai Warriors': 1,
#              'Kessen I': 1,
#              'Nintendo Entertainment': 1,
#              'United States': 1,
#              'G Maple': 1,
#              'Inazuma Eleven': 1,
#              'Chrono Stone': 1,
#              'God Series': 1,
#              'Two Qiaos': 1,
#              'Creative Assembly': 1,
#              'Total War': 1})
