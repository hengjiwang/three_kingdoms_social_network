# %%
import pandas as pd
import numpy as np

# %%
people = pd.read_csv('./data/people.csv')

# %%
people = people.name_en.values

# %%
count = pd.read_csv('./data/count-1-120.csv')

# %%
names = count.name.values

# %%
for name in names:
    if name not in people:
        print(name)
# Out:
# Lu Bu
# Zhao Zilong
# Prime Minister
# South Land
# Latter Ruler
# Imperial Protector
# Your Majesty
# First Ruler
# If I
# Lu Meng
# General Who
# The Emperor
# But I
# Then Cao
# Zhang Ni
# The Latter
# Yue Jing
# Now I
# Hu Ban
# Then Zhuge
# O Prime
# The Ruler
# When Cao
# River Land
# The Prime
# Great River
# River Wei
# So I
# But Liu
# Then Zhang
# Gao Ding
# Yellow River
# River Lands
# Middle Land
# Yellow Scarves
# So Cao
# West River
# Imperial Uncle
# River Huai
# Imperial Guardian
# Regent Marshal
# When Liu
# Then Liu
# Xie Valley
# The Prince
# Van Leader
# But Cao
# West Valley
# Valley Land
# When I
# The First
# Sima Yan
# And I
# Yangping Pass
# His Majesty
# The Governor
# Diao Chan
# So Liu
# Red Hare
# Then I
# Ji Ping
# Yi Ji
# Zhang Jue
# O Prince
# Grand Commander
# Lu Fan
# Yang Song
# Ma Zheng
# Saber Pass
# The Imperial
# When Sun
# Zhou Cang
# Sleeping Dragon
# Ling Bao
# Yong Kai
# Then Sun
# Directing Instructor
# When Zhuge
# Fu Shiren
# ...
